# %% [markdown]
# LetsGrowMore Virtual Internship Program April 2022 Intern - Vrushali Varankar Task 2 - Image to Pencil sketch with python
#
# Importing the Libraries

# %%
import numpy as np
import cv2
from PIL import Image
from IPython.display import display

# %%
img  =  cv2.imread("pic4.jpg")
img = cv2.resize(img,(200,300))
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0xE3BBA838E0>

# %% [markdown]
# Converting image to Greayscale image

# %%
greyscale_img =  cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(greyscale_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0xE3BC58E130>

# %%
neg_img = cv2.bitwise_not(greyscale_img)
display(Image.fromarray(neg_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0xE3BDBD6100>

# %%
smooth_img = cv2.GaussianBlur(neg_img, (5,5), 0, 0)
display(Image.fromarray(smooth_img))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0xE3BC57EEB0>

# %%
sketch_img = 255 - smooth_img
sketch = cv2.divide(greyscale_img, sketch_img, scale=250.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=200x300 at 0xE3BC57EDF0>

# %% [markdown]
# Comparison between original image and pencil sketch

# %%
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=200x300 at 0xE3BC43F790>
# <PIL.Image.Image image mode=L size=200x300 at 0xE3BC57EFA0>
